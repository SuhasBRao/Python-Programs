# %% [markdown]
# ## Its a task to unlock the secret message in the word_matrix.png

# %%
from PIL import Image

# %%
mask = Image.open('mask.png')

# %%
new_mask = mask.resize((1015,559))

# %%
word_matrix = Image.open('word_matrix.png')

# %%
word_matrix.size
# Out:
# (1015, 559)

# %%
word_matrix.putalpha(185)

# %%
temp = new_mask.putalpha(215)
#new_mask.paste(im=word_matrix, box=(0,0),mask = word_matrix)
new_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x1FF18290AC8>

# %%
new_mask.paste(im=word_matrix, box=(0,0),mask = word_matrix)

# %%
new_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x1FF18290AC8>

# %%
word_matrix.paste(im=new_mask, box=(0,0),mask = new_mask)

# %%
word_matrix
